# %% [markdown]
# <a href="https://colab.research.google.com/github/TabyH/MathData24/blob/main/MathData_Class1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/en/thumb/4/40/Florida_Atlantic_Owls_logo.svg/1200px-Florida_Atlantic_Owls_logo.svg.png" width=400>

# %% [markdown]
# <img src = "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTzjbjsZ5ibePq5V-ubtXqX8pikj1eQqXbUHw&s" width= 300>

# %%
apples = 10

# %%
oranges = 8

# %%
total = apples + oranges

# %%
total
# Out:
# 18

# %%
print(total)
# Out:
# 18

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
A = np.random.random()

# %%
A
# Out:
# 0.13699007246941886

# %%
A = np.random.random((1,5))

# %%
A
# Out:
# array([[0.20796678, 0.68652404, 0.19347831, 0.98535383, 0.75385445]])

# %%
B = np.random.random((1,5))

# %%
A,B
# Out:
# (array([[0.20796678, 0.68652404, 0.19347831, 0.98535383, 0.75385445]]),
#  array([[0.99941564, 0.90331581, 0.40623829, 0.29262019, 0.34386301]]))

# %%
A = A.T
B = B.T

# %%
A,B
# Out:
# (array([[0.20796678],
#         [0.68652404],
#         [0.19347831],
#         [0.98535383],
#         [0.75385445]]),
#  array([[0.99941564],
#         [0.90331581],
#         [0.40623829],
#         [0.29262019],
#         [0.34386301]]))

# %%
plt.plot(A,B)

# %%
plt.plot(A,B,'r.')

# %%
X = np.random.random((100,1))
Y = np.random.random((100,1))
plt.plot(X,Y,'g--')

# %%
A.shape
B.shape
X.shape
Y.shape
# Out:
# (100, 1)

# %%
print(A.shape,B.shape,X.shape,Y.shape)
# Out:
# (5, 1) (5, 1) (100, 1) (100, 1)

# %%
Z = np.random.random((100,100))

# %%
Z.shape
# Out:
# (100, 100)

# %%
Z
# Out:
# array([[0.27563717, 0.72869879, 0.54956804, ..., 0.37969663, 0.96759087,
#         0.04645184],
#        [0.95305286, 0.30292814, 0.17194604, ..., 0.07097816, 0.85093294,
#         0.29698821],
#        [0.93309714, 0.74836867, 0.93405654, ..., 0.55280708, 0.06971635,
#         0.3510124 ],
#        ...,
#        [0.67186741, 0.77227571, 0.6789269 , ..., 0.98716847, 0.14748728,
#         0.7258744 ],
#        [0.64914275, 0.2352431 , 0.56380609, ..., 0.50446237, 0.26906506,
#         0.46674178],
#        [0.53574961, 0.51800331, 0.64419162, ..., 0.09524727, 0.09780181,
#         0.78376183]])

# %%
plt.imshow(Z)
